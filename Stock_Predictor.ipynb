# %% [markdown]
# #Introduction
#
# In this notebook we will create the time series model that will be uploaded onto our streamlit web app. Now our web app will have the capability to predict stock price for up to 10 days ahead! This is an improvement from the last stock predictor (check it out here https://github.com/kamilalfian/stock-predictor) and hopefully the quality of the prediction is agood enough and can be improved in the future
#
# We will be using INTP.JK which is a stock ticker for PT Indocement Tunggal Prakarsa Tbk that we will use for our model training. First we import the necessary libraries including pandas_datareader overridden by yfin that we will use to load our stock price data.

# %%
#Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import yfinance as yfin
yfin.pdr_override()

# %% [markdown]
# Next we load our stock price dataframe using yfin. The dataframe is a table consisting of following features:
#
# 1. Open: The opening price during that day
# 2. High: The highest price during that day
# 3. Low: The lowest price during that day
# 4. Close: The closing price during that day
# 5. Adj Close: Adjusted Close Price
# 6. Volume: The volume of stocks being traded

# %%
#fetching our dataframe

start='2013-01-01'
end='2023-10-31'
df=yfin.download('INTP.JK',start,end)
df.head(30)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close   Volume
# Date
# 2013-01-02  21900.0  22600.0  21850.0  21900.0  14190.923828  3921000
# 2013-01-03  21950.0  22300.0  21700.0  21950.0  14223.321289  4714500
# 2013-01-04  22050.0  22200.0  21750.0  22050.0  14288.120117  4995000
# 2013-01-07  21850.0  22100.0  21800.0  21850.0  14158.524414  2262500
# 2013-01-08  22100.0  22250.0  21800.0  22100.0  14320.519531  3296500
# 2013-01-09  21900.0  22150.0  21750.0  21900.0  14190.923828  4266000
# 2013-01-10  21300.0  21900.0  21250.0  21300.0  13802.130859  3564500
# 2013-01-11  21400.0  21600.0  21300.0  21400.0  13866.927734  1987500
# 2013-01-14  21600.0  21800.0  21500.0  21600.0  13996.527344  1543000
# 2013-01-15  21850.0  21950.0  21600.0  21850.0  14158.524414  3659500
# 2013-01-16  21900.0  21950.0  21700.0  21900.0  14190.923828  1270000
# 2013-01-17  21800.0  21900.0  21500.0  21800.0  14126.124023  1047500
# 2013-01-18  22050.0  22050.0  21750.0  22050.0  14288.120117  4041500
# 2013-01-21  21500.0  22050.0  21350.0  21500.0  13931.726562  3620500
# 2013-01-22  21500.0  21500.0  21500.0  21500.0  13931.726562        0
# 2013-01-23  21550.0  21700.0  21250.0  21550.0  13964.125977  3889500
# 2013-01-25  21600.0  21850.0  21350.0  21600.0  13996.527344  3514500
# 2013-01-28  21350.0  21700.0  21250.0  21350.0  13834.529297  2111000
# 2013-01-29  21700.0  21700.0  21350.0  21700.0  14061.324219  3024000
# 2013-01-30  21650.0  21650.0  21400.0  21650.0  14028.926758  3118000
# 2013-01-31  21750.0  21750.0  21450.0  21750.0  14093.724609  2798000
# 2013-02-01  21500.0  21800.0  21500.0  21500.0  13931.726562  3175000
# 2013-02-04  21450.0  21700.0  21400.0  21450.0  13899.327148  3237000
# 2013-02-05  21500.0  21650.0  21400.0  21500.0  13931.726562  3331500
# 2013-02-06  21550.0  21700.0  21450.0  21550.0  13964.125977  2288000
# 2013-02-07  21550.0  21650.0  21350.0  21550.0  13964.125977  3137000
# 2013-02-08  21400.0  21900.0  21400.0  21400.0  13866.927734  4809500
# 2013-02-11  21450.0  21600.0  21400.0  21450.0  13899.327148   467500
# 2013-02-12  21700.0  21700.0  21400.0  21700.0  14061.324219  1858000
# 2013-02-13  21900.0  21950.0  21550.0  21900.0  14190.923828  3791000

# %% [markdown]
# And then we process the dataframe by resetting the index, and then dropping unnecessary features.

# %%
#resetting index so we can drop it later since we don't need 'Date' column.

df=df.reset_index()
df.head()
# Out:
#         Date     Open     High      Low    Close     Adj Close   Volume
# 0 2013-01-02  21900.0  22600.0  21850.0  21900.0  14190.923828  3921000
# 1 2013-01-03  21950.0  22300.0  21700.0  21950.0  14223.321289  4714500
# 2 2013-01-04  22050.0  22200.0  21750.0  22050.0  14288.120117  4995000
# 3 2013-01-07  21850.0  22100.0  21800.0  21850.0  14158.524414  2262500
# 4 2013-01-08  22100.0  22250.0  21800.0  22100.0  14320.519531  3296500

# %%
#Drop unnecessary features.

df=df.drop(['Date','Adj Close'],axis=1)
df.head()
# Out:
#       Open     High      Low    Close   Volume
# 0  21900.0  22600.0  21850.0  21900.0  3921000
# 1  21950.0  22300.0  21700.0  21950.0  4714500
# 2  22050.0  22200.0  21750.0  22050.0  4995000
# 3  21850.0  22100.0  21800.0  21850.0  2262500
# 4  22100.0  22250.0  21800.0  22100.0  3296500

# %% [markdown]
# Below is a little bit of how our rendered closing price history chart looks like.

# %%
plt.plot(df.Close)

# %% [markdown]
# And then below we will try to calculate its daily MA100 and MA200. MA stands on moving average and it is usually used by technicalist as indicators to predict moving trend.

# %%
ma100=df.Close.rolling(100).mean()
ma100
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 2678    10316.75
# 2679    10312.75
# 2680    10304.25
# 2681    10293.75
# 2682    10287.00
# Name: Close, Length: 2683, dtype: float64

# %%
#plotting MA100

plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r',label='ma100')
plt.legend()
plt.show()

# %% [markdown]
# Below we tried to plot both MA100 and MA200. As you can see whenever MA100 (red line) passed the MA200 (yellow line) on upward direction, the closing price tends to rise and vice versa. This is because MA100 represents the most recent moving force and such most recent moving force represents the likeliest direction the stock price will go.

# %%
#plotting MA100 and MA200 together

ma200=df.Close.rolling(200).mean()
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r',label='ma100')
plt.plot(ma200,'y',label='ma200')
plt.legend()
plt.show()

# %% [markdown]
# Exploratory data analysis above concluded that moving average are patterns that we can use to predict the closing price of future dates. And that is what we are going to do next. We will create a model that takes the last 100 days' closing price and then use them to predict next 10 days' price.
#
# First, let's separate between training and testing data. We will use 70:30 rule.

# %%
#splitting data into training/test
train=pd.DataFrame(df.Close[0:int(len(df)*0.7)])
test=pd.DataFrame(df.Close[int(len(df)*0.7):int(len(df))])

# %% [markdown]
# And then we scale the data so it will be compatible with our neural network model. I personally have tried this and not scaling our data will result in our model not being able to calculate the error/losses, hence impossible to evaluate.

# %%
#scale our training data

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
train=scaler.fit_transform(train)

# %% [markdown]
# Like I mentioned before, we will predict the closing price of the next 10 days by using the last 100 days' closing price. So we can consider the last 100 days' price as our features (x_train) and the next day's price as our target (y_train). Let's create them.

# %%
#separating x_train and y_train

x_train = []
y_train = []
for i in range(100, train.shape[0]-9):
    x_train.append(train[i-100:i])
    y_train.append(train[i:i+10,0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %% [markdown]
# And then we import libraries and create our model.

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model=Sequential()
#first layer
model.add(LSTM(units=50, activation='tanh', return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))
#second layer
model.add(LSTM(units=120, activation='tanh'))
model.add(Dropout(0.2))
#final layer
model.add(Dense(units=10))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 120)               82080
#
#  dropout_1 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 10)                1210
#
# =================================================================
# Total params: 93690 (365.98 KB)
# Trainable params: 93690 (365.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# We will create our own custom loss function that we will use to evaluate our model. The purpose for this custom function is to give bigger weight to our most recent days' closing price, a trait that is not exclusively exhibited by other loss function such as "mean_squared_error".
#
# After that we will compile our built model with the custom loss function we just created and then fit our model to our data.

# %%
import keras.backend as K

def custom_loss(y_test, y_predicted):
    # Assuming y_true and y_pred are tensors with arbitrary dimensions

    # Flatten the tensors to 1D arrays
    y_true_flat = K.flatten(y_test)
    y_pred_flat = K.flatten(y_predicted)

    # Assign higher weight to more recent data
    weights = K.arange(1, K.shape(y_true_flat)[0] + 1, dtype='float32')
    weights = K.reverse(weights, axes=0)
    weights /= K.sum(weights)

    # Calculate mean squared error with weighted samples
    loss = K.mean(weights * K.square(y_true_flat - y_pred_flat), axis=-1)

    return loss

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Compile model
model.compile(optimizer='adam',loss=custom_loss)

# Define the EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='loss',  # Monitor loss
    patience=8,           # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore the model weights from the epoch with the best validation loss
)

# Train model
model.fit(x_train,y_train,epochs=80,callbacks=[early_stopping])
# Out:
# Epoch 1/80
# 56/56 [==============================] - 15s 23ms/step - loss: 1.8705e-04
# Epoch 2/80
# 56/56 [==============================] - 1s 23ms/step - loss: 3.8185e-05
# Epoch 3/80
# 56/56 [==============================] - 2s 30ms/step - loss: 3.2388e-05
# Epoch 4/80
# 56/56 [==============================] - 1s 17ms/step - loss: 2.9241e-05
# Epoch 5/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.7821e-05
# Epoch 6/80
# 56/56 [==============================] - 1s 10ms/step - loss: 3.0457e-05
# Epoch 7/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.7589e-05
# Epoch 8/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.3192e-05
# Epoch 9/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.2793e-05
# Epoch 10/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.2018e-05
# Epoch 11/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.0571e-05
# Epoch 12/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.1111e-05
# Epoch 13/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.0845e-05
# Epoch 14/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.0472e-05
# Epoch 15/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.0744e-05
# Epoch 16/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.0426e-05
# Epoch 17/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.8929e-05
# Epoch 18/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.8683e-05
# Epoch 19/80
# 56/56 [==============================] - 1s 10ms/step - loss: 2.1550e-05
# Epoch 20/80
# 56/56 [==============================] - 1s 13ms/step - loss: 1.8260e-05
# Epoch 21/80
# 56/56 [==============================] - 1s 14ms/step - loss: 1.7267e-05
# Epoch 22/80
# 56/56 [==============================] - 1s 14ms/step - loss: 1.7951e-05
# Epoch 23/80
# 56/56 [==============================] - 1s 14ms/step - loss: 1.6745e-05
# Epoch 24/80
# 56/56 [==============================] - 1s 14ms/step - loss: 1.7874e-05
# Epoch 25/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.6741e-05
# Epoch 26/80
# 56/56 [==============================] - 1s 9ms/step - loss: 1.6404e-05
# Epoch 27/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.6392e-05
# Epoch 28/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.6659e-05
# Epoch 29/80
# 56/56 [==============================] - 1s 9ms/step - loss: 1.6055e-05
# Epoch 30/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.6976e-05
# Epoch 31/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.5692e-05
# Epoch 32/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.4872e-05
# Epoch 33/80
# 56/56 [==============================] - 1s 9ms/step - loss: 1.5639e-05
# Epoch 34/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.5800e-05
# Epoch 35/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.5569e-05
# Epoch 36/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.4739e-05
# Epoch 37/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.5120e-05
# Epoch 38/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.4644e-05
# Epoch 39/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.4733e-05
# Epoch 40/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3905e-05
# Epoch 41/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.6685e-05
# Epoch 42/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.6066e-05
# Epoch 43/80
# 56/56 [==============================] - 1s 13ms/step - loss: 1.4190e-05
# Epoch 44/80
# 56/56 [==============================] - 1s 13ms/step - loss: 1.4283e-05
# Epoch 45/80
# 56/56 [==============================] - 1s 13ms/step - loss: 1.4598e-05
# Epoch 46/80
# 56/56 [==============================] - 1s 13ms/step - loss: 1.6339e-05
# Epoch 47/80
# 56/56 [==============================] - 1s 14ms/step - loss: 1.4937e-05
# Epoch 48/80
# 56/56 [==============================] - 1s 11ms/step - loss: 1.3519e-05
# Epoch 49/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3453e-05
# Epoch 50/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.5621e-05
# Epoch 51/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3624e-05
# Epoch 52/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3126e-05
# Epoch 53/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3513e-05
# Epoch 54/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3161e-05
# Epoch 55/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3562e-05
# Epoch 56/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3635e-05
# Epoch 57/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2791e-05
# Epoch 58/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2820e-05
# Epoch 59/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2959e-05
# Epoch 60/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3009e-05
# Epoch 61/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2985e-05
# Epoch 62/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2706e-05
# Epoch 63/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2830e-05
# Epoch 64/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2722e-05
# Epoch 65/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2483e-05
# Epoch 66/80
# 56/56 [==============================] - 1s 13ms/step - loss: 1.3112e-05
# Epoch 67/80
# 56/56 [==============================] - 1s 14ms/step - loss: 1.3141e-05
# Epoch 68/80
# 56/56 [==============================] - 1s 14ms/step - loss: 1.3149e-05
# Epoch 69/80
# 56/56 [==============================] - 1s 13ms/step - loss: 1.2830e-05
# Epoch 70/80
# 56/56 [==============================] - 1s 14ms/step - loss: 1.2668e-05
# Epoch 71/80
# 56/56 [==============================] - 1s 11ms/step - loss: 1.2691e-05
# Epoch 72/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.1824e-05
# Epoch 73/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.3024e-05
# Epoch 74/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2680e-05
# Epoch 75/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2695e-05
# Epoch 76/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2601e-05
# Epoch 77/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2100e-05
# Epoch 78/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2526e-05
# Epoch 79/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.2397e-05
# Epoch 80/80
# 56/56 [==============================] - 1s 10ms/step - loss: 1.1779e-05

# %% [markdown]
# We have just fitted our model with our training data. Now let's test our model on our test data. But we will have to append our testing data to our last 100 days' data so our first row testing data have something to predict from. We will call our appended testing data 'input_data'. Don't forget to scale input_data also.

# %%
#Appending test data to past 100 data, and scale it

past100=pd.DataFrame(df.Close[0:int(len(df)*0.7)]).tail(100)
final_df=past100.append(test,ignore_index=True)
input_data=scaler.transform(final_df)
input_data
# Out:
# <ipython-input-17-3a18aecfb25d>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=past100.append(test,ignore_index=True)
# array([[ 0.42432815],
#        [ 0.4115983 ],
#        [ 0.39745403],
#        [ 0.36492221],
#        [ 0.40311174],
#        [ 0.42574257],
#        [ 0.45120226],
#        [ 0.45544554],
#        [ 0.45403112],
#        [ 0.41301273],
#        [ 0.3748232 ],
#        [ 0.36350778],
#        [ 0.34229137],
#        [ 0.33804809],
#        [ 0.31966054],
#        [ 0.30127298],
#        [ 0.27015559],
#        [ 0.35360679],
#        [ 0.32390382],
#        [ 0.32107496],
#        [ 0.24752475],
#        [ 0.25601132],
#        [ 0.23338048],
#        [ 0.15700141],
#        [ 0.15700141],
#        [ 0.15700141],
#        [ 0.02828854],
#        [ 0.03818953],
#        [ 0.        ],
#        [ 0.10466761],
#        [ 0.06082037],
#        [ 0.06082037],
#        [ 0.17680339],
#        [ 0.23055163],
#        [ 0.17821782],
#        [ 0.1824611 ],
#        [ 0.16407355],
#        [ 0.14427157],
#        [ 0.14992928],
#        [ 0.20792079],
#        [ 0.17680339],
#        [ 0.12871287],
#        [ 0.13154173],
#        [ 0.12164074],
#        [ 0.13295615],
#        [ 0.12871287],
#        [ 0.0834512 ],
#        [ 0.09618105],
#        [ 0.09476662],
#        [ 0.08062235],
#        [ 0.12022631],
#        [ 0.09618105],
#        [ 0.07355021],
#        [ 0.06930693],
#        [ 0.07213579],
#        [ 0.10042433],
#        [ 0.13437058],
#        [ 0.08910891],
#        [ 0.08486563],
#        [ 0.07496464],
#        [ 0.07496464],
#        [ 0.12022631],
#        [ 0.12871287],
#        [ 0.08628006],
#        [ 0.08628006],
#        [ 0.07779349],
#        [ 0.08628006],
#        [ 0.08062235],
#        [ 0.08486563],
#        [ 0.10325318],
#        [ 0.11739745],
#        [ 0.16548798],
#        [ 0.15983027],
#        [ 0.23903819],
#        [ 0.23338048],
#        [ 0.20792079],
#        [ 0.20509194],
#        [ 0.22772277],
#        [ 0.18953324],
#        [ 0.14851485],
#        [ 0.1669024 ],
#        [ 0.16548798],
#        [ 0.13719943],
#        [ 0.18387553],
#        [ 0.17963225],
#        [ 0.13437058],
#        [ 0.16831683],
#        [ 0.17680339],
#        [ 0.15841584],
#        [ 0.17114569],
#        [ 0.15983027],
#        [ 0.15417256],
#        [ 0.14144272],
#        [ 0.14285714],
#        [ 0.12588402],
#        [ 0.145686  ],
#        [ 0.145686  ],
#        [ 0.15134371],
#        [ 0.13719943],
#        [ 0.14851485],
#        [ 0.13861386],
#        [ 0.13154173],
#        [ 0.13295615],
#        [ 0.13578501],
#        [ 0.13719943],
#        [ 0.15275813],
#        [ 0.16407355],
#        [ 0.15417256],
#        [ 0.17114569],
#        [ 0.16973126],
#        [ 0.17680339],
#        [ 0.1669024 ],
#        [ 0.17114569],
#        [ 0.17397454],
#        [ 0.17680339],
#        [ 0.17538897],
#        [ 0.14851485],
#        [ 0.15134371],
#        [ 0.17256011],
#        [ 0.17397454],
#        [ 0.14710042],
#        [ 0.14144272],
#        [ 0.14285714],
#        [ 0.14427157],
#        [ 0.14427157],
#        [ 0.15134371],
#        [ 0.15275813],
#        [ 0.14285714],
#        [ 0.145686  ],
#        [ 0.17680339],
#        [ 0.16973126],
#        [ 0.16548798],
#        [ 0.16831683],
#        [ 0.14710042],
#        [ 0.16548798],
#        [ 0.17114569],
#        [ 0.14427157],
#        [ 0.13437058],
#        [ 0.15275813],
#        [ 0.15417256],
#        [ 0.13437058],
#        [ 0.08910891],
#        [ 0.07496464],
#        [ 0.11598303],
#        [ 0.12022631],
#        [ 0.11881188],
#        [ 0.09335219],
#        [ 0.13154173],
#        [ 0.08910891],
#        [ 0.08486563],
#        [ 0.07072136],
#        [ 0.07496464],
#        [ 0.09193777],
#        [ 0.07072136],
#        [ 0.06506365],
#        [ 0.06364922],
#        [ 0.08486563],
#        [ 0.07637907],
#        [ 0.07213579],
#        [ 0.07496464],
#        [ 0.08769448],
#        [ 0.09052334],
#        [ 0.08486563],
#        [ 0.09052334],
#        [ 0.10749646],
#        [ 0.12588402],
#        [ 0.13437058],
#        [ 0.14285714],
#        [ 0.14851485],
#        [ 0.15417256],
#        [ 0.1612447 ],
#        [ 0.17963225],
#        [ 0.17680339],
#        [ 0.17256011],
#        [ 0.1669024 ],
#        [ 0.16548798],
#        [ 0.16973126],
#        [ 0.15417256],
#        [ 0.1824611 ],
#        [ 0.21640736],
#        [ 0.22065064],
#        [ 0.27298444],
#        [ 0.30551627],
#        [ 0.28712871],
#        [ 0.28995757],
#        [ 0.2758133 ],
#        [ 0.2758133 ],
#        [ 0.2758133 ],
#        [ 0.27298444],
#        [ 0.28995757],
#        [ 0.35077793],
#        [ 0.33239038],
#        [ 0.30693069],
#        [ 0.31824611],
#        [ 0.30834512],
#        [ 0.28429986],
#        [ 0.32531825],
#        [ 0.3125884 ],
#        [ 0.29844413],
#        [ 0.28429986],
#        [ 0.31683168],
#        [ 0.29137199],
#        [ 0.2970297 ],
#        [ 0.29137199],
#        [ 0.2970297 ],
#        [ 0.281471  ],
#        [ 0.31541726],
#        [ 0.32531825],
#        [ 0.31400283],
#        [ 0.31117397],
#        [ 0.27015559],
#        [ 0.26874116],
#        [ 0.29561528],
#        [ 0.28995757],
#        [ 0.29420085],
#        [ 0.29561528],
#        [ 0.29278642],
#        [ 0.27298444],
#        [ 0.29561528],
#        [ 0.3125884 ],
#        [ 0.30410184],
#        [ 0.30410184],
#        [ 0.30975955],
#        [ 0.30834512],
#        [ 0.31541726],
#        [ 0.36067893],
#        [ 0.36067893],
#        [ 0.3592645 ],
#        [ 0.34229137],
#        [ 0.33521924],
#        [ 0.33521924],
#        [ 0.33804809],
#        [ 0.28288543],
#        [ 0.22772277],
#        [ 0.23196605],
#        [ 0.27298444],
#        [ 0.29420085],
#        [ 0.281471  ],
#        [ 0.24752475],
#        [ 0.25884017],
#        [ 0.26591231],
#        [ 0.26166902],
#        [ 0.26591231],
#        [ 0.2602546 ],
#        [ 0.25884017],
#        [ 0.25884017],
#        [ 0.23479491],
#        [ 0.24328147],
#        [ 0.25176803],
#        [ 0.23479491],
#        [ 0.22630835],
#        [ 0.21499293],
#        [ 0.2135785 ],
#        [ 0.1824611 ],
#        [ 0.20509194],
#        [ 0.25459689],
#        [ 0.23338048],
#        [ 0.23338048],
#        [ 0.22630835],
#        [ 0.22489392],
#        [ 0.22630835],
#        [ 0.2291372 ],
#        [ 0.21640736],
#        [ 0.18953324],
#        [ 0.19094767],
#        [ 0.19519095],
#        [ 0.20650636],
#        [ 0.25601132],
#        [ 0.2446959 ],
#        [ 0.22630835],
#        [ 0.21074965],
#        [ 0.22065064],
#        [ 0.21499293],
#        [ 0.21074965],
#        [ 0.18811881],
#        [ 0.1669024 ],
#        [ 0.1824611 ],
#        [ 0.1669024 ],
#        [ 0.16407355],
#        [ 0.17680339],
#        [ 0.17680339],
#        [ 0.17963225],
#        [ 0.1669024 ],
#        [ 0.1669024 ],
#        [ 0.20226308],
#        [ 0.20650636],
#        [ 0.21216407],
#        [ 0.18811881],
#        [ 0.19943423],
#        [ 0.19236209],
#        [ 0.18811881],
#        [ 0.19943423],
#        [ 0.19236209],
#        [ 0.1824611 ],
#        [ 0.18953324],
#        [ 0.21782178],
#        [ 0.20226308],
#        [ 0.18528996],
#        [ 0.17538897],
#        [ 0.17680339],
#        [ 0.18104668],
#        [ 0.16831683],
#        [ 0.17963225],
#        [ 0.17963225],
#        [ 0.17963225],
#        [ 0.16831683],
#        [ 0.15558699],
#        [ 0.15558699],
#        [ 0.14427157],
#        [ 0.13719943],
#        [ 0.13719943],
#        [ 0.12305516],
#        [ 0.14992928],
#        [ 0.15983027],
#        [ 0.17397454],
#        [ 0.18528996],
#        [ 0.17538897],
#        [ 0.17114569],
#        [ 0.14851485],
#        [ 0.13578501],
#        [ 0.13437058],
#        [ 0.11881188],
#        [ 0.11881188],
#        [ 0.10749646],
#        [ 0.11032532],
#        [ 0.0990099 ],
#        [ 0.09759547],
#        [ 0.08769448],
#        [ 0.08769448],
#        [ 0.09759547],
#        [ 0.09759547],
#        [ 0.09052334],
#        [ 0.06647808],
#        [ 0.07072136],
#        [ 0.05799151],
#        [ 0.06647808],
#        [ 0.06930693],
#        [ 0.05091938],
#        [ 0.07496464],
#        [ 0.05940594],
#        [ 0.06223479],
#        [ 0.07779349],
#        [ 0.07920792],
#        [ 0.07213579],
#        [ 0.06223479],
#        [ 0.06223479],
#        [ 0.08062235],
#        [ 0.0523338 ],
#        [ 0.06930693],
#        [ 0.06364922],
#        [ 0.05657709],
#        [ 0.04950495],
#        [ 0.03536068],
#        [ 0.0155587 ],
#        [-0.00424328],
#        [-0.02687412],
#        [-0.00282885],
#        [ 0.03253182],
#        [ 0.04101839],
#        [ 0.03677511],
#        [ 0.04950495],
#        [ 0.04526167],
#        [ 0.04950495],
#        [ 0.07213579],
#        [ 0.07779349],
#        [ 0.0834512 ],
#        [ 0.10891089],
#        [ 0.0990099 ],
#        [ 0.10325318],
#        [ 0.12022631],
#        [ 0.10042433],
#        [ 0.11173975],
#        [ 0.09618105],
#        [ 0.10325318],
#        [ 0.12022631],
#        [ 0.11173975],
#        [ 0.10325318],
#        [ 0.10466761],
#        [ 0.10325318],
#        [ 0.10891089],
#        [ 0.09476662],
#        [ 0.06082037],
#        [ 0.08062235],
#        [ 0.0834512 ],
#        [ 0.07213579],
#        [ 0.08062235],
#        [ 0.07637907],
#        [ 0.07072136],
#        [ 0.06364922],
#        [ 0.05799151],
#        [ 0.07496464],
#        [ 0.07779349],
#        [ 0.07072136],
#        [ 0.06930693],
#        [ 0.07355021],
#        [ 0.0678925 ],
#        [ 0.08062235],
#        [ 0.06930693],
#        [ 0.03818953],
#        [ 0.04526167],
#        [ 0.03536068],
#        [ 0.03536068],
#        [ 0.05091938],
#        [ 0.05091938],
#        [ 0.04243281],
#        [ 0.05799151],
#        [ 0.09335219],
#        [ 0.12588402],
#        [ 0.11739745],
#        [ 0.12446959],
#        [ 0.12729844],
#        [ 0.12022631],
#        [ 0.12164074],
#        [ 0.10891089],
#        [ 0.10466761],
#        [ 0.11881188],
#        [ 0.13295615],
#        [ 0.14427157],
#        [ 0.15134371],
#        [ 0.145686  ],
#        [ 0.15983027],
#        [ 0.19660537],
#        [ 0.19377652],
#        [ 0.17538897],
#        [ 0.19236209],
#        [ 0.18528996],
#        [ 0.17538897],
#        [ 0.17963225],
#        [ 0.15983027],
#        [ 0.16548798],
#        [ 0.14710042],
#        [ 0.14427157],
#        [ 0.13295615],
#        [ 0.13437058],
#        [ 0.11881188],
#        [ 0.11739745],
#        [ 0.10042433],
#        [ 0.07496464],
#        [ 0.07072136],
#        [ 0.07355021],
#        [ 0.08628006],
#        [ 0.0834512 ],
#        [ 0.10183876],
#        [ 0.15983027],
#        [ 0.16265912],
#        [ 0.16973126],
#        [ 0.15417256],
#        [ 0.15417256],
#        [ 0.14851485],
#        [ 0.14992928],
#        [ 0.15700141],
#        [ 0.13719943],
#        [ 0.12022631],
#        [ 0.12164074],
#        [ 0.13437058],
#        [ 0.13154173],
#        [ 0.13578501],
#        [ 0.13295615],
#        [ 0.14427157],
#        [ 0.13154173],
#        [ 0.13295615],
#        [ 0.15983027],
#        [ 0.13719943],
#        [ 0.12446959],
#        [ 0.1145686 ],
#        [ 0.10608204],
#        [ 0.09476662],
#        [ 0.09335219],
#        [ 0.09335219],
#        [ 0.09759547],
#        [ 0.10183876],
#        [ 0.10183876],
#        [ 0.09052334],
#        [ 0.09052334],
#        [ 0.07920792],
#        [ 0.0834512 ],
#        [ 0.08486563],
#        [ 0.10466761],
#        [ 0.09476662],
#        [ 0.10042433],
#        [ 0.09193777],
#        [ 0.09476662],
#        [ 0.09476662],
#        [ 0.09759547],
#        [ 0.09193777],
#        [ 0.09052334],
#        [ 0.10749646],
#        [ 0.08910891],
#        [ 0.09052334],
#        [ 0.08910891],
#        [ 0.09335219],
#        [ 0.08486563],
#        [ 0.09052334],
#        [ 0.09618105],
#        [ 0.10466761],
#        [ 0.09335219],
#        [ 0.10891089],
#        [ 0.10608204],
#        [ 0.09759547],
#        [ 0.0678925 ],
#        [ 0.09476662],
#        [ 0.07072136],
#        [ 0.0523338 ],
#        [ 0.0523338 ],
#        [ 0.0523338 ],
#        [ 0.04101839],
#        [ 0.04384724],
#        [ 0.08062235],
#        [ 0.07920792],
#        [ 0.07920792],
#        [ 0.07779349],
#        [ 0.07920792],
#        [ 0.08628006],
#        [ 0.09618105],
#        [ 0.07637907],
#        [ 0.08910891],
#        [ 0.09193777],
#        [ 0.09618105],
#        [ 0.09618105],
#        [ 0.09052334],
#        [ 0.0834512 ],
#        [ 0.09335219],
#        [ 0.08486563],
#        [ 0.08203678],
#        [ 0.09052334],
#        [ 0.08910891],
#        [ 0.06930693],
#        [ 0.06647808],
#        [ 0.06647808],
#        [ 0.04809052],
#        [ 0.05374823],
#        [ 0.05091938],
#        [ 0.04384724],
#        [ 0.04243281],
#        [ 0.05657709],
#        [ 0.05374823],
#        [ 0.04950495],
#        [ 0.04950495],
#        [ 0.04809052],
#        [ 0.0678925 ],
#        [ 0.06506365],
#        [ 0.0678925 ],
#        [ 0.04101839],
#        [ 0.04243281],
#        [ 0.06930693],
#        [ 0.04950495],
#        [ 0.02121641],
#        [ 0.01838755],
#        [ 0.03536068],
#        [ 0.0311174 ],
#        [ 0.03536068],
#        [ 0.04526167],
#        [ 0.0523338 ],
#        [ 0.0523338 ],
#        [ 0.06082037],
#        [ 0.05374823],
#        [ 0.02545969],
#        [ 0.03253182],
#        [ 0.02970297],
#        [ 0.03536068],
#        [ 0.0155587 ],
#        [ 0.02121641],
#        [ 0.01272984],
#        [ 0.00707214],
#        [-0.00707214],
#        [-0.00282885],
#        [-0.00990099],
#        [-0.00424328],
#        [-0.00141443],
#        [-0.00424328],
#        [ 0.00707214],
#        [ 0.        ],
#        [ 0.01272984],
#        [ 0.02828854],
#        [ 0.02687412],
#        [ 0.01980198],
#        [ 0.01272984],
#        [ 0.01131542],
#        [ 0.00707214],
#        [-0.00424328],
#        [-0.00282885],
#        [ 0.00282885],
#        [-0.00848656],
#        [-0.00565771],
#        [-0.00848656],
#        [-0.01131542],
#        [-0.01414427],
#        [-0.01272984],
#        [-0.00848656],
#        [ 0.        ],
#        [ 0.00565771],
#        [ 0.00282885],
#        [ 0.00707214],
#        [ 0.00990099],
#        [ 0.        ],
#        [-0.00424328],
#        [-0.00424328],
#        [-0.00424328],
#        [ 0.00141443],
#        [-0.00848656],
#        [-0.00707214],
#        [-0.00990099],
#        [ 0.01980198],
#        [ 0.02404526],
#        [ 0.02687412],
#        [ 0.02121641],
#        [ 0.02545969],
#        [ 0.02263083],
#        [ 0.02687412],
#        [ 0.0155587 ],
#        [ 0.01272984],
#        [ 0.00141443],
#        [-0.00424328],
#        [-0.00282885],
#        [ 0.        ],
#        [ 0.01272984],
#        [ 0.00424328],
#        [ 0.00141443],
#        [ 0.00282885],
#        [ 0.00141443],
#        [ 0.00990099],
#        [ 0.00141443],
#        [ 0.01131542],
#        [ 0.00990099],
#        [ 0.00990099],
#        [ 0.0155587 ],
#        [ 0.01697313],
#        [ 0.01980198],
#        [ 0.01414427],
#        [ 0.02121641],
#        [ 0.02263083],
#        [ 0.01838755],
#        [ 0.03677511],
#        [ 0.03677511],
#        [ 0.0466761 ],
#        [ 0.04950495],
#        [ 0.04526167],
#        [ 0.04809052],
#        [ 0.04243281],
#        [ 0.03394625],
#        [ 0.0311174 ],
#        [ 0.02545969],
#        [ 0.01272984],
#        [ 0.00707214],
#        [ 0.00141443],
#        [-0.00141443],
#        [-0.00848656],
#        [-0.00848656],
#        [-0.00990099],
#        [ 0.00424328],
#        [-0.00424328],
#        [-0.00707214],
#        [-0.01272984],
#        [-0.00707214],
#        [-0.00141443],
#        [ 0.00848656],
#        [-0.00424328],
#        [-0.00141443],
#        [ 0.        ],
#        [-0.00848656],
#        [-0.00141443],
#        [-0.00424328],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.0523338 ],
#        [ 0.0466761 ],
#        [ 0.0466761 ],
#        [ 0.0678925 ],
#        [ 0.07072136],
#        [ 0.05516266],
#        [ 0.05091938],
#        [ 0.0678925 ],
#        [ 0.05516266],
#        [ 0.05799151],
#        [ 0.0466761 ],
#        [ 0.0311174 ],
#        [ 0.01980198],
#        [ 0.03536068],
#        [ 0.02687412],
#        [ 0.01980198],
#        [ 0.02263083],
#        [ 0.02687412],
#        [ 0.03536068],
#        [ 0.03677511],
#        [ 0.03253182],
#        [ 0.03818953],
#        [ 0.04101839],
#        [ 0.04101839],
#        [ 0.03677511],
#        [ 0.03960396],
#        [ 0.03818953],
#        [ 0.03536068],
#        [ 0.03677511],
#        [ 0.04101839],
#        [ 0.04101839],
#        [ 0.03960396],
#        [ 0.03253182],
#        [ 0.03818953],
#        [ 0.03394625],
#        [ 0.03253182],
#        [ 0.03253182],
#        [ 0.02121641],
#        [ 0.02687412],
#        [ 0.0311174 ],
#        [ 0.04526167],
#        [ 0.04243281],
#        [ 0.03677511],
#        [ 0.03536068],
#        [ 0.03818953],
#        [ 0.03253182],
#        [ 0.02828854],
#        [ 0.01980198],
#        [ 0.04384724],
#        [ 0.05657709],
#        [ 0.04384724],
#        [ 0.05091938],
#        [ 0.05799151],
#        [ 0.05657709],
#        [ 0.05516266],
#        [ 0.03960396],
#        [ 0.0311174 ],
#        [ 0.04101839],
#        [ 0.02970297],
#        [ 0.02828854],
#        [ 0.03253182],
#        [ 0.0466761 ],
#        [ 0.03536068],
#        [ 0.0311174 ],
#        [ 0.04101839],
#        [ 0.03536068],
#        [ 0.06082037],
#        [ 0.07496464],
#        [ 0.09618105],
#        [ 0.08486563],
#        [ 0.09476662],
#        [ 0.09618105],
#        [ 0.12446959],
#        [ 0.12022631],
#        [ 0.13719943],
#        [ 0.12729844],
#        [ 0.12022631],
#        [ 0.09759547],
#        [ 0.10325318],
#        [ 0.12022631],
#        [ 0.11315417],
#        [ 0.10891089],
#        [ 0.10325318],
#        [ 0.0990099 ],
#        [ 0.10466761],
#        [ 0.11315417],
#        [ 0.10466761],
#        [ 0.12164074],
#        [ 0.1145686 ],
#        [ 0.11173975],
#        [ 0.12446959],
#        [ 0.12446959],
#        [ 0.12446959],
#        [ 0.0990099 ],
#        [ 0.09759547],
#        [ 0.05516266],
#        [ 0.02687412],
#        [ 0.04101839],
#        [ 0.04809052],
#        [ 0.04526167],
#        [ 0.04526167],
#        [ 0.03818953],
#        [ 0.08203678],
#        [ 0.07637907],
#        [ 0.08203678],
#        [ 0.07072136],
#        [ 0.06930693],
#        [ 0.06647808],
#        [ 0.02545969],
#        [ 0.03536068],
#        [ 0.03536068],
#        [ 0.05940594],
#        [ 0.06364922],
#        [ 0.0523338 ],
#        [ 0.05657709],
#        [ 0.05940594],
#        [ 0.06082037],
#        [ 0.06647808],
#        [ 0.06930693],
#        [ 0.08910891],
#        [ 0.0466761 ],
#        [ 0.04101839],
#        [ 0.04101839],
#        [ 0.04101839],
#        [ 0.05091938],
#        [ 0.06082037],
#        [ 0.0523338 ],
#        [ 0.05374823],
#        [ 0.0523338 ],
#        [ 0.0523338 ],
#        [ 0.05657709],
#        [ 0.06223479],
#        [ 0.0523338 ],
#        [ 0.05799151],
#        [ 0.03960396],
#        [ 0.04384724],
#        [ 0.04526167],
#        [ 0.04384724],
#        [ 0.0523338 ],
#        [ 0.05799151],
#        [ 0.03536068],
#        [ 0.03536068],
#        [ 0.02828854],
#        [ 0.02404526],
#        [ 0.01697313],
#        [ 0.01980198],
#        [ 0.02970297],
#        [ 0.02970297],
#        [ 0.02828854],
#        [ 0.03677511],
#        [ 0.02687412],
#        [ 0.03394625],
#        [ 0.02828854],
#        [ 0.02970297],
#        [ 0.02828854],
#        [ 0.02970297],
#        [ 0.02687412],
#        [ 0.03677511],
#        [ 0.02263083],
#        [ 0.01838755],
#        [ 0.02545969],
#        [ 0.03536068],
#        [ 0.04809052],
#        [ 0.0466761 ],
#        [ 0.05657709],
#        [ 0.04950495],
#        [ 0.05516266],
#        [ 0.06082037],
#        [ 0.05657709],
#        [ 0.05657709],
#        [ 0.05091938],
#        [ 0.06082037],
#        [ 0.06082037],
#        [ 0.06647808],
#        [ 0.05940594],
#        [ 0.0523338 ],
#        [ 0.06364922],
#        [ 0.06506365],
#        [ 0.06506365],
#        [ 0.07355021],
#        [ 0.10325318],
#        [ 0.10325318],
#        [ 0.08769448],
#        [ 0.08203678],
#        [ 0.09618105],
#        [ 0.09759547],
#        [ 0.0990099 ],
#        [ 0.11315417],
#        [ 0.11032532],
#        [ 0.11173975],
#        [ 0.10891089],
#        [ 0.09759547],
#        [ 0.0990099 ],
#        [ 0.10183876],
#        [ 0.10608204],
#        [ 0.1145686 ],
#        [ 0.10608204],
#        [ 0.10466761],
#        [ 0.09193777],
#        [ 0.08062235],
#        [ 0.07496464],
#        [ 0.07496464],
#        [ 0.08062235],
#        [ 0.08486563],
#        [ 0.08062235],
#        [ 0.08769448],
#        [ 0.0990099 ],
#        [ 0.08769448],
#        [ 0.09759547],
#        [ 0.09193777],
#        [ 0.0834512 ],
#        [ 0.05516266],
#        [ 0.06082037],
#        [ 0.04809052],
#        [ 0.05516266],
#        [ 0.0466761 ],
#        [ 0.04243281],
#        [ 0.02970297],
#        [ 0.04526167],
#        [ 0.03818953],
#        [ 0.0466761 ],
#        [ 0.0466761 ],
#        [ 0.04243281],
#        [ 0.04809052],
#        [ 0.04243281],
#        [ 0.04101839],
#        [ 0.0466761 ],
#        [ 0.03818953],
#        [ 0.04384724],
#        [ 0.04101839],
#        [ 0.04526167],
#        [ 0.05799151],
#        [ 0.03536068],
#        [ 0.03394625],
#        [ 0.0311174 ],
#        [ 0.02121641],
#        [ 0.02263083],
#        [ 0.02121641],
#        [ 0.00424328],
#        [-0.00141443],
#        [-0.00282885]])

# %%
input_data.shape
# Out:
# (905, 1)

# %% [markdown]
# And then we separate them into x_test and y_test just like we did with x_train and y_train.

# %%
#Separate x_test and y_test

x_test=[]
y_test=[]
for i in range(100, input_data.shape[0]-9):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i:i+10,0])

x_test, y_test = np.array(x_test), np.array(y_test)

# %% [markdown]
# After that we predict our closing price using x_test. Our prediction is called 'y_prediction'. Then we will compare y_prediction with y_test to measure our mean squared error. Lastly we will plot both our y_predicted and y_test to visualize just how precise our model is.

# %%
#Making prediction

y_predicted=model.predict(x_test)
# Out:
# 25/25 [==============================] - 1s 7ms/step

# %%
#Measure Mean Squared Error

from sklearn.metrics import mean_squared_error

y_predicted=y_predicted*(scaler.data_max_-scaler.data_min_)+scaler.data_min_
y_test=y_test*(scaler.data_max_-scaler.data_min_)+scaler.data_min_
mse = mean_squared_error(y_test, y_predicted)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 313351.62609546154

# %%
#Plot y_predicted vs y_test

plt.figure(figsize=(12,6))
plt.plot(y_test,'b',label='original price')
plt.plot(y_predicted,'r',label='predicted price')
plt.xlabel('time')
plt.ylabel('price')
plt.legend()
plt.show()

# %% [markdown]
# It turns out our model did not too bad even though its MSE of ~300000 is far above our last stock predictor (for 1 day) that can achieve MSE as low as 65000. This translates our current stock predictor to Mean Absolute Error of around 550. This means that on average our prediction will only deviates against our actual data by ~550 Indonesian Rupiah. Regardless, the y_predicted (predicted price)  seems to fit fairly well with our y_test (original price) in the chart we just plotted. So this is not a bad start.
#
# Now that our model is good enough, let's save the model. We will load this model in our .py file which will be uploaded to streamlit web app.

# %%
model.save('model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
